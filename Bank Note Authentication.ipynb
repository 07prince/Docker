# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('C:\\Users\\pshah\\Desktop\\ml_ krishniyak\\data_set\\BankNote_Authentication.csv')

# %%
df.head(2)
# Out:
#    variance  skewness  curtosis  entropy  class
# 0    3.6216    8.6661   -2.8073 -0.44699      0
# 1    4.5459    8.1674   -2.4586 -1.46210      0

# %%
x=df.drop('class',axis=1)
y=df['class']

# %%
x_train, x_test, y_train, y_test = train_test_split(
...     x, y, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rf.predict(x_test)

# %%
score=accuracy_score(y_test,y_pred)

# %%
score
# Out:
# 0.9927272727272727

# %%
rf.predict([[1,3,-2,-8]])
# Out:
# C:\Users\pshah\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
import pickle
pickle_out=open('rf','wb')

# %%
pickle.dump(rf,pickle_out)
pickle_out.close()
